# %%
import pandas as pd

# %%
try: 
    if results_df is None:
        results_df = pd.read_csv('CVresults.csv', index_col=0)
except:
    results_df = pd.read_csv('CVresults.csv', index_col=0)

# %%
results_df
# Out:
#     batch_size  learning_rate  patience    CVmean     CVstd
# 0        182.0       0.003504       4.0  0.022479  0.016433
# 1        292.0       0.006135       2.0  0.018253  0.002704
# 2        101.0       0.004132       2.0  0.016210  0.002896
# 3        353.0       0.005314       3.0  0.018254  0.007249
# 4        122.0       0.003516       3.0  0.016758  0.004927
# 5        275.0       0.005848       4.0  0.015482  0.004256
# 6        143.0       0.007752       3.0  0.016167  0.003167
# 7        232.0       0.004652       3.0  0.017872  0.006589
# 8        236.0       0.005519       3.0  0.018521  0.006562
# 9        523.0       0.003899       2.0  0.019322  0.005525
# 10       272.0       0.004404       3.0  0.017294  0.002799
# 11       195.0       0.004957       3.0  0.015569  0.003458
# 12       297.0       0.006410       2.0  0.018201  0.003817
# 13       138.0       0.003301       4.0  0.014897  0.003021
# 14       238.0       0.008018       3.0  0.017473  0.003360
# 15       277.0       0.010216       2.0  0.020879  0.006078
# 16       162.0       0.003862       2.0  0.049195  0.093211
# 17       185.0       0.003071       4.0  0.016582  0.003090
# 18       274.0       0.006466       2.0  0.018775  0.002707
# 19       303.0       0.006760       2.0  0.020171  0.004983
